# %% [markdown]
# # Shingle Dependency Trees for datasketch's Minhash

# %%
import sys
sys.path.append("..")

# %%
import conllu
import treesimi as ts
import datasketch
import json
import itertools

# %% [markdown]
# ## Load Dataset

# %%
# %%capture
# !mkdir "../data"
# !wget -O "../data/de_hdt-ud-dev.conllu" "https://raw.githubusercontent.com/UniversalDependencies/UD_German-HDT/master/de_hdt-ud-dev.conllu"

# %%
dat = conllu.parse(open("../data/de_hdt-ud-dev.conllu").read())
len(dat)
# Out:
# 18434

# %% [markdown]
# # Generate Shingles and Build LSH
# - `MinHashLSH` -- LSH is updatable, Threshold is fixed, Num results unknown (Redis support)
# - `MinHashLSHForest` -- LSH is updatable, Threshold unknown, Top-N are returned
# - `MinHashLSHEnsemble` -- LSH is fixed, Threshold is fixed (Redis support)

# %%
# %%time

cfg = {
    'use_trunc_leaves': False,
    'use_drop_nodes': False,
    'use_replace_attr': False
}

# Instantiate LSH Forest
lsh1 = datasketch.MinHashLSH(num_perm=256, threshold=0.8)
lsh2 = datasketch.MinHashLSHForest(num_perm=256)
lsh3 = datasketch.MinHashLSHEnsemble(num_perm=256, threshold=0.8, num_part=32)
lsh3examples = []

mhash = []
for i in range(len(dat)):
    # Read tree data 
    adjac = [(t['id'], t['head'], t['deprel']) for t in dat[i]]
    nested = ts.adjac_to_nested_with_attr(adjac)
    nested = ts.remove_node_ids(nested)
    
    # Shingling
    shingled = ts.shingleset(nested, **cfg)
    stringified = [json.dumps(tree).encode('utf-8') for tree in shingled]

    # Create MinHash objects
    m = datasketch.MinHash(num_perm=256)
    for s in stringified:
        m.update(s)
    
    # Add to LSH
    lsh1.insert(i, m)
    lsh2.add(i, m)
    lsh3examples.append((i, m, len(stringified)))
    
    # save objects
    mhash.append(m)

# Call index method for LSH Forest
lsh2.index()
# Call index method to build the whole LSH Ensemble
lsh3.index(tuple(lsh3examples))
# Out:
# CPU times: user 2min 11s, sys: 1.68 s, total: 2min 13s
# Wall time: 2min 37s

# %% [markdown]
# # Query for the top-N results

# %% [markdown]
# ## Just LSH
# Finds just itself.

# %%
"""
j = 1
res = lsh1.query(mhash[j])

print(f"#num results: {len(res)}")
for i in res:
    print(f"{i:>8d}: {dat[i].metadata['text']}")
"""
None

# %%
# try to find any clusters of similar sentences
results = []
for j in range(len(mhash)):
    results.append(lsh1.query(mhash[j]))

# %%
# number of examples with at least 1 similar example
tmp = [res for res in results if len(res) >= 2]
n_examples = set(itertools.chain(*tmp))
print(len(n_examples))
# Out:
# 2757
# #num results: 2
#       48 | 1.0000 | Toysmart.com hatte seinen Kunden zugesichert , dass ihre Daten nicht an Dritte weitergegeben würden .
#     4760 | 0.6836 | Diese Zahl muss man aber per Telefon an die Sendezentrale durchgeben , damit dort der Gewinner ermittelt werden kann .

# %%
res = tmp[8]
print(f"#num results: {len(res)}")
j = res[0]
for i in res:
    print(f"{i:>8d} | {mhash[i].jaccard(mhash[j]):6.4f} | {dat[i].metadata['text']}")
# Out:
# #num results: 2
#       60 | 1.0000 | Im Vergleich zum Vorjahr ist die Zahl der deutschen Internet-Teilnehmer um rund 60 Prozent gestiegen .
#     7286 | 0.6211 | Etwa 95 Prozent des innerdeutschen E-Mail-Austauschs werde heute über DE-CIX in Frankfurt am Main abgewickelt .

# %% [markdown]
# ## Top-N Results (LSH Forest)

# %%
j = 1
res = lsh2.query(mhash[j], 5)
print(f"#num results: {len(res)}")
for i in res:
    #print(f"{i:>8d}: {dat[i].metadata['text']}")
    print(f"{i:>8d} | {mhash[i].jaccard(mhash[j]):6.4f} | {dat[i].metadata['text']}")
# Out:
# #num results: 5
#        1 | 1.0000 | Begleitet von Marktgerüchten über den bevorstehenden Konkurs von Amazon , setzt die Aktie des Online-Händlers ihre Talfahrt fort .
#      486 | 0.2695 | Man habe das eCash-Verfahren in Zusammenarbeit mit DigiCash erfolgreich weiterentwickelt .
#     8712 | 0.3203 | Die Prüflinge in Bayern müssen die Prüfung am 21. Juni erneut ablegen .
#    16017 | 0.2812 | Der Besuch beim Zahnarzt könnte bald seinen Schrecken verlieren .
#    10258 | 0.3359 | Der Internethandel mit Wertpapieren hat in letzter Zeit einen Boom erlebt .

# %% [markdown]
# ## Containment Query (LSH Ensemble)

# %%
j = 2
res = [key for key in lsh3.query(lsh3examples[j][1], lsh3examples[j][2])]
print(f"#num results: {len(res)}")
for i in res:
    #print(f"{i:>8d}: {dat[i].metadata['text']}")
    print(f"{i:>8d} | {mhash[i].jaccard(mhash[j]):6.4f} | {dat[i].metadata['text']}")
# Out:
# #num results: 946
#     9216 | 0.2070 | In Europa wurde 6,2 Prozent weniger verkauft , in den USA 3,3 Prozent .
#     9217 | 0.3672 | Nur im asiatischen Pazifikraum erzielte die Branche einen Wachstum von 2 Prozent .
#        3 | 0.3672 | Im Januar hatte die Aktie noch einen Höchststand von 24,50 Euro erreicht .
#    12311 | 0.2656 | In elektrische Signale umgewandelt , lassen sich die minimalen Widerstandsänderungen zur Tonübertragung nutzen .
#    15895 | 0.3984 | Ab kommenden Mittwoch verkauft Aldi-Nord einen neuen Medion-PC für 2298 Mark ( ohne Monitor ) .
#     5145 | 0.2656 | Der Wertpapierhandel an deutschen Präsenzbörsen wird von 17.30 auf 20 Uhr ausgedehnt .
#    11291 | 0.2539 | Beide Unternehmen erklärten übereinstimmend , dies sei wegen Finanzierungsschwierigkeiten nicht vollzogen worden .
#     7710 | 0.2227 | Unter Myers wurden die Aufgaben des Space Command für den Informationskrieg massiv ausgebaut .
#      549 | 0.2969 | Damit ist man vor dem ShareSniffer und ähnlichen Port-Scannern sicher .
#    13365 | 0.2383 | Genauere Informationen zur bei DVD-Video eingesetzten CSS-Verschlüsselung enthält die aktuelle c't-Ausgabe 20/99 .
#     2615 | 0.2734 | Bei Nachforschungen stießen Vertreter des Rechenzentrums schließlich auf einen umfangreichen Datenbestand mit kinderpornografischen Fotos .
#     6206 | 0.2539 | Demnach darf sogar eine Behörde für sich Betriebs- und Geschäftsgeheimnisse in Anspruch nehmen .
#    11328 | 0.3633 | Cubin war mit diesem Vorschlag bereits im letzten Jahr im Senat gescheitert .
#    15426 | 0.3086 | In Westeuropa habe Deutschland mit 13 Prozent des Marktes den größten Anteil .
#       73 | 0.2266 | Sie erhielten in Brüssel Rückendeckung durch den für Informationstechnik zuständigen EU-Kommissar Martin Bangemann .
#    14411 | 0.3047 | Der Direktversender hatte erst vor kurzem seine Low-Cost-Modelle mit AMD-Prozessoren aus dem Sortiment gestrichen .
#    18005 | 0.2422 | Nicht-Mitglieder wie comNetworld müssen die Domainanträge ihrer Endkunden folglich über ein Mitglied abwickeln .
#    13398 | 0.2422 | Solange die MPAA den Cryptome-Betreiber John Young nicht verklagt , bleiben die Seiten im Netz .
#    16473 | 0.2617 | Weit vorn liegt nach wie vor der Apache mit 2350748 .
#      611 | 0.3125 | Für viele Anbieter rechne sich die Werbefinanzierung ihrer Online-Auftritten auf Dauer nicht .
#    14438 | 0.3633 | Zum 50. " Prospektjubiläum " präsentiert der MediaMarkt nun ein 15-ZOLL-TFT-Display für 999 DM .
#     8301 | 0.2422 | Im September hatte es noch eine Woche nach dem Beben Probleme bei der Stromversorgung gegeben .
#    11889 | 0.2383 | " Wir dürfen einfach nicht den Zugang zu der im Usenet gesammelten Weisheit verlieren . "
#     1657 | 0.3711 | Der Kunde bezahlt hierfür neben dem jährlichen Grundpreis von fünf Euro keine Transaktionsgebühren .
#     2171 | 0.2695 | Unter einem neuen Markennamen will AOL in Großbritannien einen gebührenfreien Dienst mit abgespeckten Inhalten einführen .
#    12414 | 0.1992 | Die Verteidigerin Kathleen Sullivan , Dekanin der Stanford Law School , sieht in DeCSS ein neutrales Werkzeug .
#    11907 | 0.2891 | Über das ARD-Portal sind 36 öffentlich-rechtliche Radiosender nach Themen sortiert als Webradio erreichbar .
#    12936 | 0.2148 | In Zukunft will sich das Unternehmen auf MetaStream , ein 3D-Visualisierungswerkzeug für E-Commerce , konzentrieren .
#    10378 | 0.2539 | " Im Vergleich zu früheren Jahren haben wir eine sehr zugespitzte Situation . "
#     3211 | 0.3672 | Bei AMD-Prozessoren kann man damit aber maximal eine Taktsteigerung um 30 Prozent erreichen .
#     5771 | 0.2070 | Mit Hilfe des neuen Standards sind ohne Zusatzaufwand Transaktionen über Bankengrenzen hinweg möglich .
#    12436 | 0.2578 | Allerdings werde sich das Abkommen " unter Umständen auch auf die Vergabe von Diplomarbeitsthemen auswirken " .
#    16022 | 0.3594 | Gelangt der Bohrer gefährlich nahe an einen Nerv , so warnt RoboDent mit einem akustischen Signal .
#    14490 | 0.2578 | Am Mittwoch offeriert Aldi wieder einmal einen PC für knapp 2000 DM .
#    13981 | 0.2305 | Wann das System wieder voll funktionsfähig sein wird , war auf Anfrage nicht zu erfahren .
#     9377 | 0.2539 | 100 Milliarden Mark , so seine Schätzungen , würden jährlich durch Cybercrime verursacht .
#     7848 | 0.2109 | Die von Siemens entwickelte Standardsoftware rückt dies nun in den Bereich des Möglichen .
#    12970 | 0.2188 | Corel übernimmt zum 1. Juli 2000 auch den Support für diese Produkte .
#     2223 | 0.2891 | Auch eine Reihe anderer Anbieter ist zur Weihnachtszeit mit Sondertarifen auf den Markt gekommen .
#    15536 | 0.2461 | Mit dem neu vorgestellten " Xbox-Xommunicator " können sich die Kontrahenten bei Netzwerkspielen sogar unterhalten .
#    14523 | 0.2773 | Wer solch ein faules Ei erworben hat , erhält im Austausch eine echte CD-RW .
#     1723 | 0.2695 | Ein möglicher Punkt für Einsparungen seien die Telefonzellen , von denen jede dritte laut Sommer unrentabel ist .
#    11457 | 0.2578 | Für einen Zeitraum von zwei Wochen sollen die Foren noch gesichert werden können .
#    17089 | 0.3242 | Ein externes Modem und eine kleine Tastatur sind bereits als Zubehör geplant .
#    17606 | 0.3047 | Laut Dell-Pressesprecher Andreas Mahl wird der WebPC aber in Deutschland vorerst nicht an den Start gehen .
#    14023 | 0.2969 | Via AMR-Adapter hat der MakroMarkt noch ein internes 56K-Modem ( HAMR5600 ) eingebaut .
#    13516 | 0.2539 | Nach dieser handelt es sich bei der DVD-Verschlüsselung um ein Geschäftsgeheimnis der DVD CCA .
#    15052 | 0.3164 | Der Messenger reagiert zum Teil jedoch erst nach mehrmaligen Aufruf der Mail nicht mehr .
#    11468 | 0.3008 | Eine bekannte Eigenart des Navigators , die sich mit dem Alter scheinbar verfestigt .
#     7887 | 0.2969 | Bis dahin wollen die USA unter den 33 Wassenaar-Mitgliedstaaten einen breiten Konsens herstellen .
#     5845 | 0.3047 | Ab dem 25.10.99 will die Deutsche Bahn auf ausgewählten Strecken Tickets per Internet verkaufen .
#    11478 | 0.2422 | In dieser Hinsicht wird sogar das an sich schon sehr einnehmende Wesen der Microsoft-Produkte übertroffen .
#    14040 | 0.3594 | Ungeachtet der Intel-Vorgaben werden einige Board-Hersteller aber trotzdem Hauptplatinen mit drei RIMM-Sockeln auf den Markt bringen .
#     5343 | 0.2422 | Die Euphorie war riesengroß , ein Ende der Hausse schien überhaupt nicht in Sicht .
#     3296 | 0.3086 | Mit dem vorliegenden Installer lässt sich Darwin allerdings noch nicht auf Intel-Rechnern einrichten .
#    16610 | 0.2695 | Die Software ist laut Hersteller ab Mitte April lieferbar - in zwei Varianten :
#      227 | 0.3047 | Zeitgleich schlugen die Ermittlungsbehörden in 21 Staaten weltweit zu - mit ähnlichem Erfolg :
#    14052 | 0.2422 | Erste Systeme mit dem Athlon-850 sollen bereits im März verfügbar sein .
#    17126 | 0.3438 | Ins Silizium gelangt der Entwurf dann in einem rekonfigurierbaren Chip der Firma Elixent .
#     3305 | 0.2578 | Die Apple Developer Connection will demnächst eine CD-ROM für 20 US-Dollar anbieten .
#     4333 | 0.2305 | Sie hält eine Eröffnung bereits im April nächsten Jahres für möglich .
#     4855 | 0.2383 | Analysten sehen dennoch auf dem noch jungen Markt gute Chancen für die Redmonder Nachzügler .
#    13566 | 0.2617 | Doch selbst ohne diese Hürde wäre der Vertrieb einer US-DVD hier zu Lande untersagt :
#    12034 | 0.1680 | Erweiterbar ist das Paket um Module , mit denen Zusatzfunktionen realisiert werden .
#    13577 | 0.3203 | Komplett in Java implementiert , unterstützt der Viewer Java Scripting entsprechend der VRML-2.0-Java-API-Spezifikation .
#     5387 | 0.3164 | Doch dort scheint das Besetzzeichen zur Regel geworden zu sein .
#    17165 | 0.1875 | Mit dem Rocket eBook-Format können im Grunde alle Online-Ausgaben der Tageszeitungen gelesen werden .
#     8974 | 0.3164 | Das Institut analysierte 40 bundesweite Publikationen auf die für IT-Spezialisten geschalteten Anzeigen .
#    15125 | 0.2695 | Die Hälfte der Jobs soll innerhalb der nächsten zwölf Monate in Großbritannien wegfallen .
#    17182 | 0.2188 | FreeNet bietet keine Möglichkeit , eine zur Verfügung gestellte Datei zu sperren .
#     8993 | 0.2617 | " Wir werden auf keinen Fall vorpreschen " , erklärte T-Online-Sprecher Jörg Lammers auf Nachfrage .
#    14629 | 0.3242 | Damit diese Strategie aufgeht , müssen Pentium-4-Systeme deutlich im Preis sinken .
#     8999 | 0.2852 | Hinter vorgehaltener Hand trifft man auch bei AOL auf deutliche Zweifel an der Idee .
#     1838 | 0.2930 | Dabei gehe es schließlich nicht nur um E-Commerce , sondern beispielsweise auch um die Verfolgung illegaler Inhalte .
#    17711 | 0.2852 | " Eigentlich war unsere Linkliste noch harmloser als die , um die es in Braunschweig ging .
#     2870 | 0.2656 | Die entsprechende Setup-Datei ist zwar noch nicht verlinkt , kann aber direkt vom US-Server geladen werden .
#    12091 | 0.2344 | Mit immer neuen Fristen vertröstet Strato seit dem gestrigen Dienstagnachmittag seine Kunden .
#     4928 | 0.3164 | Laut Opera arbeitet er aber in der Classic-Umgebung von Apples neuem Betriebssystem .
#    15682 | 0.2617 | Suns bisheriges Flaggschiff , die E10000 , ist inzwischen in Ehren ergraut .
#    17732 | 0.3086 | Nur durch die Eingabe von bei der Installation definierten Hotkeys kommt man ins Konfigurationsmenü .
#     7492 | 0.2773 | Ein Gutachten soll den neuen TKÜV-Entwurf auf Wirtschaftlichkeitsaspekte überprüfen , ein anderes soll das Sicherheitsniveau evaluieren .
#    12614 | 0.2617 | In den ersten Tagen nach der Installation zeigt Opera nur ein statisches Werbe-Banner für den Browser selbst .
#     6472 | 0.1875 | Die Implementierung in nationales Recht würde die Verschärfung bundesdeutscher Gesetze nach sich ziehen .
#     8009 | 0.2539 | Über den verbleibenden starken Einfluss insbesondere der US-Regierung gab es schon am Vortag emotionalisierte Diskussionen .
#     2379 | 0.3242 | AOL startet heute in Großbritannien den gebührenfreien Internet-Zugang " Netscape Online " .
#     2892 | 0.3320 | Durch die in Merlin intergrierte Spracherkennung wird man über gerpochene Befehle durchs WWW navigieren können :
#     2895 | 0.2578 | Noch immer gibt es keine offiziellen Details über die geplanten Tarifsenkungen der Telekom .
#     6481 | 0.3242 | Doch das Parlament hat die Ratsentschließungen nur zur Kenntnis zu nehmen .
#    12117 | 0.2422 | Neben der technischen Zusicherung einer bestimmten Leistung denkt Strato zukünftig auch an " wirtschaftliche Zusicherungen gegenüber den Kunden " .
#    14166 | 0.3672 | Der angegebene Preis von 2999 Mark verstünde sich zudem zuzüglich Mehrwertsteuer .
#    16224 | 0.3086 | Er stellt derzeit in seiner ursprünglichen Version 45,12 % der 1834710 antwortenden Web-Server .
#    12131 | 0.2500 | Eine Überspannung - die bislang vermutete Ursache - bezeichnete er als " wilde Theorie " .
#    17767 | 0.1680 | Deren " Home Audio Visual Interoperability " ( HAVI ) getaufte Architektur soll mit Jini kooperieren können .
#    18279 | 0.3242 | Zur Wahl stehen bislang diverse US-amerikanische Call-By-Call-Anbieter , ein AOL- und ein Compaq.NET-Zugang .
#    13162 | 0.2031 | Wie beim Vorgänger läßt sich auch das DigiTheatre DTS per Fernbedienung steuern .
#     7023 | 0.2031 | Shayler veröffentlicht immer wieder Geheimdienstmaterialien , die peinliche Fehlschläge der Nachrichtendienste aufdecken .
#    11137 | 0.2930 | Ab Mitte September steht im ehemaligen Bundestag die " Physik der kondensierten Materie " im Mittelpunkt .
#     3970 | 0.2266 | Die nächste Version von Apples Multimedia-Software QuickTime soll im Sommer erscheinen .
#    17282 | 0.2930 | Die Filmindustrie fordert von RecordTV bis zu 150.000 US-Dollar je aufgezeichneter Sendung .
#     2436 | 0.3164 | Die Industrie habe jetzt ein Ziel , auf das sie zuarbeiten könne .
#     2437 | 0.3008 | Eine entsprechende Infrastruktur sei in den USA jedoch kaum vor 2004 zu erwarten .
#     3466 | 0.2344 | Apple Computer hat die finale Version seiner neuen Betriebssystemgeneration in Produktion gegeben .
#    18329 | 0.3047 | Man habe es in den letzten Tagen " unter Zeitdruck wieder zusammengebastelt " .
#    15769 | 0.3125 | Unverständlicherweise fehlt allerdings auch dem neuen Display eine Beleuchtung - der Spieler tappt also ohne ausreichend Umgebungslicht im Dunkeln .
#     3490 | 0.3125 | Noch gibt es von Apple keine offizielle Stellungnahme mit Einzelheiten zur neuen Verkaufsstrategie .
#     7589 | 0.2773 | In der Eröffnungsphase gibt es täglich Video-Live-Streamings von Konzerten internationaler Popstars .
#    11179 | 0.3047 | Callahan besitzt bereits einen Anteil von 55 Prozent an der Regionalgesellschaft Nordrhein-Westfalen .
#    12203 | 0.2852 | Zum Abspielen braucht das Gerät nicht mit einem Computer verbunden zu sein .
#     1452 | 0.3711 | Dort bringen Langzeitarbeitslose die gebrauchten PCs unter Anleitung wieder auf Vordermann und erwerben dabei eine zusätzliche Qualifikation .
#    12217 | 0.2031 | Das Umweltschutz-Department des US-Bundesstaates Massachusetts will Computerschrott zukünftig im Straßenbau recyclen .
#    11193 | 0.2188 | Die EU hat angekündigt , ab Mai den Zugang zu ihren Verwaltungsunterlagen zu öffnen .
#    15803 | 0.3750 | Am 14. September brachte Nintendo die neue Spielkonsole Gamecube in Japan auf den Markt .
#    18364 | 0.2852 | Dieses Projekt lag auf Eis , weil die EU-Kommission im Mai gravierende wettbewerbsrechtliche Bedenken angemeldet hatte .
#     5055 | 0.3164 | Bei Gefallen soll man 30 US-Dollar an eine gemeinnützige Vereinigung überweisen .
#    10692 | 0.2695 | Beim Verbraucherschutz soll hingegen das Recht des Landes gelten , in dem der Kunde wohnt .
#     3531 | 0.3672 | Allein gestern schnellte der Wert um 23 auf 108 Dollar in die Höhe .
#     3020 | 0.2578 | E-Plus und SAT.1 wollen im Juni eine neue Chat-Plattform in Betrieb nehmen :
#    10198 | 0.2578 | Eine vorsorgliche Speicherung der Daten aller Kunden bei einem Provider steht bislang aber anscheinend nicht zur Debatte .
#     7641 | 0.2422 | In einem gewaltigen Kraftakt bemühen sich dennoch alle , die Termine einzuhalten .
#     4060 | 0.3281 | Dieses Modell soll ab April zu Preisen ab 8320 DM in Deutschland erhältlich sein .
#     3036 | 0.2656 | Der Bund stellt daher rund 25 Millionen Mark für mehrere Modellprojekte zur Verfügung .
#     3039 | 0.2695 | Unter http://www.mozilla.org/download.html hat man Zugriff auf die Macintosh- , Unix- und Windows-Quellen .
#     9186 | 0.2578 | Amazon begründet diese geringere Bezahlung mit den niedrigeren Lebenshaltungskosten in den eher ländlichen Gebieten .
#    18405 | 0.2617 | Hier hat sich das US-amerikanische Unternehmen rechtzeitig Partner ins Boot geholt :
#    11247 | 0.2500 | Durch den Nationalfeiertag am 4. Juli handle es sich ohnehin um eine verkürzte Arbeitswoche .
#     8188 | 0.2188 | Das Angebot basiert auf einer Kette von Proxy-Servern , die mit Filterprogrammen ausgestattet sind .
#    10756 | 0.3086 | Diese Möglichkeit aber hatte offenbar Clemens Rasch nicht bedacht , sondern wollte gleich zur Tat schreiten .
#     1546 | 0.3008 | Über " Meine Stadt " als MSN-Partner erhält der Benutzer lokale Informationen zu etwa 14000 Gemeinden .
#    12814 | 0.2695 | Nun verklagt Adobe seinen Hauptkonkurrenten Macromedia , der seit einigen Versionen in seinen Programmen ähnliche Paletten benutzt .
#    13846 | 0.2422 | Dieselbe Kapazität auf weniger Scheiben , was auch entsprechend weniger Schreib-/Leseköpfe erfordert , senkt die Preise .
#    12827 | 0.2930 | Trotz der Umbenennung wollen die Musikkonzerne den Dienst weiterhin im Laufe des Sommers in Betrieb nehmen .
#     5660 | 0.2656 | Beim FBI ist er unter die zehn meistgesuchten Kriminellen der USA gerutscht ( http://www.fbi.gov/mostwant/tenlist.htm ) .
#     3612 | 0.2344 | Zusätzlich verwaltet es verschiedene Einwahl-Konfigurationen , mehrere T-Online-Kennungen , Mitbenutzer , eMail- und Browserprogramme .
#    11806 | 0.2500 | Die von Freiwilligen getragenen Sentinel- , Chancellor- und Advocate-Programme würden nicht fortgeführt .
#     3614 | 0.2617 | Auf Wunsch prüft eine Update-Funktion , ob eine neue Version der Software bei T-Online erhältlich ist .
#     9760 | 0.2461 | Liste von Firmen , die während der NS-Zeit Zwangsarbeiter beschäftigt haben , im Web veröffentlicht .
#     3114 | 0.2812 | Außerdem hatte Apple bereits 1993 mit dem Newton einen allerdings nur mäßig erfolgreichen PDA im Sortiment .
#     3627 | 0.2383 | Für Web-Browser gehört ein Plug-in zum Lieferumfang , das die von QuickTime unterstützten Formate für diese Programme erschließt .
#     5678 | 0.2461 | Kurz nach 18 Uhr ( US-Ostküstenzeit ) kam am Dienstag der Kommunikationssatellit Galaxy IV ins Trudeln .
#    13358 | 0.2500 | Im Web ist ein Programm aufgetaucht , das den Inhalt kopiergeschützter DVD-Videos auf Festplatten kopiert .
#    15408 | 0.3125 | Laut Dacey verfügt die IRS jedoch über keinerlei Kontrollmechanismen , um einen solchen Einbruch überhaupt zu bemerken .
#    15926 | 0.2422 | Nach den USA und Deutschland will sich jetzt auch die Schweiz auf Computer-Attacken besser vorbereiten .
#     4665 | 0.3008 | Apple will im September einen verbesserten iMac mit FireWire- und DVD-Hardware vorstellen .
#    13370 | 0.2148 | Die Anwaltskanzlei handelt im Auftrag der in Kalifornien ansässigen DVD Copy Control Association ( DVD-CCA ) .
#    10306 | 0.2422 | Computersysteme , die zum Jahreswechsel ausfallen könnten , sind in den USA kein Thema mehr .
#     8771 | 0.2734 | Ein erfahrener Systemingenieur erreicht dagegen durchschnittlich ein Jahresgehalt von 103.000 Mark - bei einer noch größeren Spanne von 42.000 Mark bis 168.000 Mark .
#    14403 | 0.2812 | Der bislang schnellste Athlon-Prozessor mit 750 MHz wird voraussichtlich schon am kommenden Montag vorgestellt .
#    14405 | 0.4141 | Der Prozessor wird in OEM-Stückzahlen zwischen 880 und 900 Dollar kosten .
#    17480 | 0.2500 | Die Sprache stellt Elemente zur Strukturierung und Bezeichnung der Elemente des User-Interface zur Verfügung .
#    17489 | 0.3086 | Ein Programmgenerator übersetzt diese dann in C++-Code , auf dem dann die eigentliche Applikationsentwicklung aufsetzt .
#    17490 | 0.2656 | Das Programm soll im Herbst gemeinsam mit der neuen Version 2.2 der Qt-Bibliothek erscheinen .
#      595 | 0.3047 | Bei ihnen findet die Geldkarte vor ecash , CyberCoin und MilliCent den meisten Zuspruch .
#    12371 | 0.2500 | Am Sonntag wurde im US-Bundesstaat Wisconsin eine Filmrolle des neuen Star-Wars-Streifens aus einem Kino gestohlen .
#    14423 | 0.3047 | Im Inneren werkeln zwei Integer-Einheiten , zwei kombinierte FPU-/"3DNow!"-Einheiten , eine Load-/Store- und eine Branch-Unit .
#     1115 | 0.2383 | Auch die Provider selbst sind eingeladen , sich auf diesem Weg bei uns zu melden .
#    14945 | 0.2031 | Nintendo will den Game Boy Advance in Europa Ende Juni 2001 ausliefern .
#    12390 | 0.2461 | Die auf Linux basierende Software des Geräts kann neben dem MPEG-1-Layer-3-Format auch das MPEG-2-Format lesen .
#     1646 | 0.2852 | In den nächsten Monaten will Paybox unter anderem Pizza-Bringdienste und Paketdienste als Akzeptanzstellen gewinnen .
#     5234 | 0.3398 | Binnen einer Stunde plumpste der Dow-Jones-Index um gut 500 Punkte ( 4,8 % ) nach unten .
#      119 | 0.3594 | Im Internet-Zeitalter dürfe sich die Musikindustrie nicht länger auf Kids als wichtigste Käuferschicht konzentrieren .
#    12926 | 0.2773 | " Maya ist die komplexeste und leistungstärkste 3D-Grafikapplikation , die jemals auf Linux lief . "
#    11392 | 0.2383 | Anwender der T9-Technik mussten im Zweifelfsfall nach der Eingabe aus einer Liste möglicher Worte auswählen .
#     4225 | 0.2383 | Die endgültige Version soll jedoch wie bereits zur WWDC angekündigt im Januar fertig sein .
#     8835 | 0.2930 | Häufiges Problem sei auch , dass ein Geschäftsführer unter Konkurrenzdruck unrealistische Projektfristen bestimme .
#     8843 | 0.2734 | 60 Prozent der Ingenieure werden sich also voraussichtlich auf Dauer mit dem Bachelor begnügen .
#     3217 | 0.5195 | Der Preis liege zwischen 60 und 80 US-Dollar , hieß es bei Xtrem .
#     4243 | 0.2930 | Statt des runden Hockey-Pucks setzt Apple jetzt auf eine optische Maus , deren komplette Oberseite als Maustaste fungiert .
#    15507 | 0.2852 | Bereits in der Vergangenheit hatte der Grafikkartenhersteller mit dieser Technik den Unmut der Online-Spieler auf sich gezogen .
#      675 | 0.2344 | Ebenfalls sei in Vorbereitung , den Mitgliedern eine kostenlose Homepage zur Verfügung zu stellen .
#    16037 | 0.3164 | Ebenso wird der Markt für Streaming-Internet-Radios und Home-Network-Receiver laut IDC nur schwach wachsen .
#    12967 | 0.2070 | Das 3D-Programm " Canoma " , mit dem 2D-Fotos in 3D-Objekte verwandelt werden können , übernimmt Adobe .
#    17577 | 0.2891 | AOL wolle gerne einen pauschal abgegoltenen Internet-Zugang für 30 bis 40 Mark anbieten .
#    11947 | 0.2891 | Besonders wichtig seien die personalisierten Dienste , mit denen der Anwender sein persönliches Informationsbedürfnis befriedigt .
#     5806 | 0.5898 | Die Graumarktpreise liegen bei fallender Tendenz zurzeit zwischen 33 und 35 Euro .
#     8886 | 0.3438 | Das Programm ist zwar möglicherweise das größte Projekt seiner Art , aber bei weitem nicht das Einzige :
#    17593 | 0.3047 | 43 Prozent der Interviewten glauben , Portale werden als Werbeplattformen immer uninteressanter .
#     7871 | 0.3047 | Das Bundesinnenministerium geht nun pünktlich zur Sommerpause mit dem Entwurf des Informationsfreiheitsgesetzes ( IFG ) wieder in die interne Beratung .
#    14018 | 0.2891 | Zum Paket für 1999 Mark gehört neben dem PC und dem Monitor auch noch ein Mountain-Bike .
#     3266 | 0.2734 | Käufer einer infizierten CD können diese bei Corel umtauschen , so eMediaweekly .
#    17603 | 0.2422 | Über die Site WebPC.com können US-amerikanische Kunden seit gestern Dells neue Internet-PCs bestellen .
#    14022 | 0.2344 | Als Prozessor dient ein Celeron mit 600 MHz , dem 64 MByte PC100-SDRAM zur Seite stehen .
#     9420 | 0.2305 | Erst fünf EU-Staaten haben ihre nationale Gesetzgebung mit den Brüsseler Vorgaben in Übereinstimmung gebracht :
#    11981 | 0.1836 | Damit können Regierungsanwälte in dem für April angesetzten Verfahren die Verfassungsmäßigkeit des DMCA verteidigen .
#    18130 | 0.2227 | In Paris hat sich heute die MP3 European Alliance ( MP3 EU ) gegründet .
#     1243 | 0.3125 | Deutsche Geldkartenbesitzer sollen künftig auch innerhalb des französischen Moneo- und des luxemburgischen MiniCash-Systems in Euro bezahlen können .
#     6369 | 0.2930 | Auch die neue Aufgabe wird vor allem eine koordinierende und forschende sein .
#    14050 | 0.3086 | Einige Berichte halten allerdings auch eine noch frühere Vorstellung am 11. Februar 2000 für wahrscheinlich .
#    16104 | 0.2891 | Mit dem Trainingssimulator sollen die Soldaten die Koordinierung und Durchführung von Einsätzen in Kleingruppen üben .
#     4335 | 0.2773 | Gerüchte , dass Apple eine eigene Ladenkette plane , existieren bereits seit längerem .
#    16642 | 0.2617 | Benchmark und Viewset sollen im Herbst kostenlos über den SPEC/GPC-Website zu beziehen sein .
#     3333 | 0.2695 | Apple hat in der Vergangenheit alle derartigen Versuche mit allen zur Verfügung stehenden rechtlichen Schritten bekämpft .
#     4362 | 0.3164 | Der Handel hat bereits reagiert und die Preise noch weiter nach unten getrieben .
#     7447 | 0.2148 | Mit dem Child Online Protection Act ( COPA ) wollte die US-Regierung 1998 Kinder vor Online-Sexangeboten schützen .
#      791 | 0.2852 | Bislang ist der Provider nur in Wuppertal , Düsseldorf und Mülheim/Ruhr zum Ortstarif erreichbar .
#     3355 | 0.2852 | Der bisherige Revo mit 8 MByte RAM bleibt weiterhin für 899 Mark im Programm .
#     7970 | 0.2656 | Das Bundeswirtschaftsministerium hat den Verbänden Eckpunkte für eine neue Telekommunikations-Überwachungsverordnung ( TKÜV ) zur Diskussion gestellt .
#    18214 | 0.2578 | Drei Anbieter von sogenannten Pet-Portals streiten sich um den mit Page-Visits gefüllten Futternapf .
#    12587 | 0.2617 | Weiterhin solle man keine Dateien ausführen , die vom Hersteller nicht digital signiert sind .
#     1327 | 0.3164 | Allerdings wird bei der Anmeldung eine Gebühr von 38 Mark fällig - eine für Telefongesellschaften ungewöhnliche Forderung .
#     1839 | 0.1641 | Auch eine Lösung , nach der generell das Recht am Standort des Anbieters gilt , sei nicht praktikabel .
#     9520 | 0.2969 | US-Unis , die traditionell .edu im Namen führen , bieten da ein anderes Bild :
#    10549 | 0.2305 | Am Freitag hat der Bundesrat über die Telekommunikationsdatenschutzverordnung ( TDSV ) entschieden , einen Anhang zum Telekommunikationsgesetz ( TKG ) .
#     6457 | 0.2500 | Drei Tage nach dieser Mitteilung muss der betreffende Titel vom Napster-Netz verschwunden sein .
#     2368 | 0.1758 | " Jedesmal , wenn jemand auf einen Pay-Button klickt , landet ein bißchen Geld bei HP . "
#    15689 | 0.2656 | Eine schnellere 900-MHz-Version der jetzigen UltraSparc-III-Chips soll laut Khan innerhalb der nächsten drei Monate verfügbar sein .
#    18257 | 0.2305 | Offensichtlich waren von Samstag Abend bis Montag um 17.00 Uhr zumindest einige Kundenpräsenzen nicht erreichbar .
#      337 | 0.3359 | Man ermittle derzeit nur wegen des Besitzes und der Verbreitung pornografischer Schriften gegen ihn .
#    12627 | 0.3125 | Trendgerecht enthält das Programm auch einen Instant Messenger , der zum ICQ-Protokoll kompatibel ist .
#    12115 | 0.1836 | Bei Strato verlautete , dass bis heute Abend zumindest die Premium-Pakete wieder online sein sollen .
#    11604 | 0.2930 | Eine weitere Erklärung , warum Snoopstar vom Netz genommen wurde , gibt der Anbieter nicht .
#     4950 | 0.2266 | Am gestrigen Montag , dem 28. August , hat Branchenkrösus Nvidia die texanische Chipschmiede 3dfx wegen Patentverletzung verklagt .
#     2392 | 0.3086 | So stieß die Auktion auch in der Redaktion auf einiges Interesse , das sich aber schnell zu Frustration wandelte .
#    13144 | 0.3281 | Die EFF hat bereits angekündigt , sie wolle den Prozess in jedem Fall zum Ende führen .
#    17258 | 0.3125 | Zum Beispiel sei zuletzt auf den Azoren ein Auspuffkrümmer eines der beiden Dieselaggregate gebrochen .
#     2923 | 0.2852 | Statt dessen ist die erste Stunde kostenlos , danach kostet jede weitere Minute 10 Pfennig .
#     8556 | 0.3125 | Gleichzeitig bedeutet das aber auch , dass die Ausbildung im Detail sehr unterschiedlich aussehen kann .
#     4463 | 0.3086 | Laut Motorola eignet sich der DSP56321 besonders für mehrkanalige Kommunikationsanwendungen , etwa Basisstationen von drahtlosen Telefonen .
#     2929 | 0.2148 | Die drei Urheber der Spezifikation hoffen , dass XKMS als Web-Standard akzeptiert wird .
#     7027 | 0.2578 | Der Geheimdienstbericht erschien auf der amerikanischen Website Cryptome.org , die auf Sicherheitsthemen spezialisiert ist .
#    15734 | 0.2852 | Die Unternehmen sollten laut Forrester am besten schon heute mit dem Aufbau eigener Netzwerke beginnen .
#     4983 | 0.2656 | Addiert man dann die ausgegebenen Seitenaufrufe zusammen , erhält man einen ungefähren Überblick über die Aktivitäten des Servers .
#      378 | 0.3477 | Die Probleme liegen laut Greskowiak beispielsweise bei der Abwicklung von Zahlungen und der digitalen Signatur .
#     3962 | 0.2422 | In Europa wird der Astro nicht erhältlich sein , so eine Sprecherin von Gateway Europa .
#     2940 | 0.2344 | Unklar ist noch , wie lange sich die Kunden vertraglich an DirectWeb binden müssen .
#    14204 | 0.2930 | Daneben gibt es auch neue MMX-Befehle für Abstandsberechnungen , Minimum/Maximum-Bestimmung und ein konditioniertes MOV .
#      895 | 0.2812 | Laut Farmer ist dies der zweite Fall in den USA , in dem ein Virus-Programmierer vor Gericht steht .
#     8064 | 0.2812 | Die jüngste Version der europäischen Abhör- und Überwachungspläne wurde diese Woche in London publik .
#    12161 | 0.2656 | Ein österreichisches Entwickler-Team hat eine Hardware-Erweiterung gebaut , mit der die Playstation MP3-Dateien abspielt .
#     1924 | 0.3828 | Nach Arcor-Berechnungen sei bei kosteneffizienter Leistungserstellung ein Monatspreis von 12 bis 15 Mark gerechtfertigt .
#    12170 | 0.1992 | Enthält eine über MailZone verschickte EMail MP3-Dateien im Attachment , wird sie nicht weitergeleitet .
#    14736 | 0.3359 | Nun beschränkt sich Ariba mit seinem Softwareangebot weiterhin auf Online-Marktplätze und das elektronische Beschaffungswesen .
#    12184 | 0.2422 | In Europa soll MP Free voraussichtlich in der zweiten Jahreshälfte erhältlich sein .
#    18335 | 0.2578 | Die Deutsche Telekom darf ihren Sonntags-Pauschaltarif ISDN-XXL ab sofort nicht mehr anbieten .
#     9126 | 0.3008 | Nach einer Marktuntersuchung von Infobeads hat der US-Einzelhandel im August überraschend viele PCs verkauft .
#    18343 | 0.2266 | Derweil hat Reg-TP-Sprecher Rudolf Boll gegenüber c't bereits angekündigt , Rechtsmittel gegen den Zwischenentscheid einzulegen .
#     2985 | 0.2227 | " Ich werde Verplichtungen der Gesellschafter im Klageweg durchsetzen " , sagte Albers dem Nachrichtenmagazin Focus .
#     2993 | 0.2617 | Mit Hilfe des FBI und von Microsoft verfolgten die Fahnder die Spuren von Kinderpornos durchs Netz .
#     4535 | 0.2539 | In den Media-Märkten würden ausschließlich die Consumer-Geräte iMac und iBook nebst Software präsentiert .
#    18361 | 0.2383 | Bis Mittwoch früh soll das beschädigte Journaling File System wieder komplett restauriert sein .
#      958 | 0.2461 | Die Resolution empfiehlt die Einrichtung einer rund um die Uhr mit Spezialisten besetzten Anlaufstelle für Ermittlungsbehörden .
#     2497 | 0.2617 | Im Handel werden die Geräte nach Angaben der Hersteller rund 100 DM kosten .
#    16323 | 0.2461 | Das VRML Consortium will VRML 2 außerdem bei der ISO als Standard einreichen .
#     3523 | 0.3008 | Die Apple-Expo-Besucher jedenfalls hoffen , auf der Messe bereits eine Mac-OS-X-CD mit nach Hause nehmen zu können .
#     4037 | 0.3477 | Sie verfügen insgesamt über 12 GByte RAM und ein halbes Terabyte Festplattenkapazität .
#    17863 | 0.2930 | AOL-Kunden können seit gestern die neue Zugangs-Software des Online-Anbieters auch in deutscher Sprache herunterladen .
#     9681 | 0.3125 | Immerhin 13 Millionen Menschen über 50 Jahre surfen oder kommunizieren im Netz .
#     7638 | 0.2578 | Die Zugangssysteme sind Ländersache und sollen zum Teil auf NT oder W2K laufen .
#     7645 | 0.2578 | Zumindest ein Bundesland ist aus Kostengründen bereits ausgestiegen , Schlewsig-Holstein hat Vorbehalte angemeldet .
#      479 | 0.2891 | Das Unternehmen war in finanzielle Schwierigkeiten geraten , als im Juni ein Millionen-Kredit ablief .
#     4076 | 0.2422 | Beim Umrechnen von Satellitenbildern in Höhenkarten arbeitete der Mac mit zwei Prozessoren tatsächlich etwa doppelt so schnell wie mit einer CPU .
#    15852 | 0.2266 | Der Sicherheitsdienstleister Daten-Treuhand.de hat ein Sicherheitsloch bei einem von ihm betreuten deutschen Kreditinstitut aufgedeckt .
#    16876 | 0.2227 | Ein ausführlicher Bericht über die Computergrafik-Konferenz SIGGRAPH erscheint in iX 9/98 , ab 13. 8. am Kiosk .
#     1006 | 0.2383 | Gleichzeitig wird das Volumen des im Basispaket enthaltenen Webspace von 50 auf 200 MByte erweitert .
#     3057 | 0.3203 | Mit 64 MByte RAM und CD-ROM-Laufwerk kostet das iBook im AppleStore 3499 Mark .
#    17914 | 0.2500 | Zum Daten-Gau des Berliner Webhosters Strato meldete sich nun auch dessen Technikpartner KPNQwest zu Wort .
#     5115 | 0.2891 | Dabei haben die Entwickler übersehen , daß dies mit Applets nicht möglich sein darf .
#     8703 | 0.3164 | Dabei war die Gewinnsteigerung mit 130 Millionen Dollar etwas größer als der Umsatzzuwachs von 120 Millionen .
#     9733 | 0.2305 | Die Auserwählten - rund 5000 von den insgesamt 1,7 Millionen DJH-Mitgliedern - dürfen dann monatlich zehn Stunden lang umsonst ins Netz .
#    15369 | 0.2266 | Weitere Verbesserungen sind ein 128-Bit-SDR-DRAM-Interface für den Bildspeicher , der vor allem bei 3D-Spielen in höheren Auflösungen zum Tragen kommt .
#     4106 | 0.2734 | Apple verlangt damit für den tragbaren Macintosh in etwa so viel wie Dell für ein vergleichbar ausgestattetes Notebook der Inspiron-Modellreihe .
#     9234 | 0.2969 | Unter anderem sollen die Gesetzeshüter leichteren Zugang zu ungeöffneten E-Mails und Telefongesprächen von Verdächtigen bekommen .
#      532 | 0.3125 | ShareSniffer sei das ideale Werkzeug , mit dem sich diese Dateien gezielt auffinden lassen .
#     7704 | 0.2852 | Er ist dann der höchstrangige Soldat der amerikanischen Streitkräfte und in dieser Funktion der wichtigste militärische Berater des Präsidenten .
#    10780 | 0.3438 | Ein Frachter hat am Sonntag versehentlich ein zentrales Daten-Unterseekabel zwischen den USA und Australien durchtrennt .
#     7196 | 0.2266 | Ist ein Song mehr als einen Monat alt , bekommt man beim Abspielversuch eine Fehlermeldung .
#    11294 | 0.2383 | In Deutschland hatte sich die Frankfurter CyberCash GmbH bereits im Dezember von ihrer gleichnamigen elektronischen Währung verabschiedet - wegen fehlenden Kundeninteresses .
#     1567 | 0.3438 | Der ursprüngliche für Donnerstagabend angesetzte Termin wurde kurzfristig auf 13 bis 14.30 Uhr vorverlegt .
#     9757 | 0.3398 | Das Verzeichnis stützte sich zum großen Teil auf Befragungen , mit Sicherheit wurden hierbei einige Firmen nicht erfasst .
#    18426 | 0.2812 | Ausserdem sei man quellenoffen und erhebe auch für die gewerbliche Nutzung der Software keine Gebühren .
#    10800 | 0.2773 | Die meisten der in Seattle vertretenen deutschen Mannschaften ziehen mit hohen Erwartungen und guten Chancen in den Wettkampf :
#    13360 | 0.3477 | Das Cracktool entschlüsselt den kompletten Inhalt einer DVD-Video und schreibt ihn im Rohformat auf die Festplatte .
#     1073 | 0.2344 | Wie die Firmensprecherin Elke Rüther gegenüber heise online sagte , müssen sich die Betroffenen nicht bei freenet.de melden .
#    10293 | 0.3008 | Die virtuelle Hochzeit von Dale und Lorrie wird deswegen nicht live im Web zu verfolgen sein .
#    14907 | 0.2695 | Von den Programmabstürzen waren nach Angaben des Landtags die Rechner von etwa 30 bis 50 Abgeordneten betroffen .
#    16956 | 0.2578 | Neben den Workstations können auch JavaStations mit StarOffice arbeiten : ein Java-Client ist Bestandteil der Suite .
#    10819 | 0.3047 | Ideal wäre eine Mischung , bei der die Spieler allgemeine Anweisungen des Trainers selbstständig im Detail umsetzen . "
#     3655 | 0.3438 | Da der Empfänger gleichzeitig aufnehmen und wiedergeben kann , funktioniert dies sogar während Live-Sendungen .
#     5192 | 0.2812 | Auch die Version 2000 , die ein halbes Jahr später auf den Markt kam , lief nicht fehlerfrei .
#     4687 | 0.2305 | Hunderte von Druckern sollen jetzt vom Betriebssystem automatisch erkannt werden , eine Treiberinstallation sei nicht notwendig .
#     3155 | 0.2969 | Alle Modelle sollen zu den gleichen Preisen wie bisher ab sofort in neuer Konfiguration erhältlich sein .
#     8278 | 0.2500 | Ohne deren Hilfe könne auch der gebildete Bürger die Masse der im Internet angebotenen Informationen nicht bewerten .
#     4186 | 0.2344 | Ferner können Live-Übertragungen jetzt über Relaisstationen verbreitet werden , womit sich die Server-Last besser verteilen lässt .
#     4700 | 0.2852 | Bis Montag sollte es aber klappen , sagte ein Händler auf Nachfrage von heise online .
#     4701 | 0.1953 | Besitzer von Mac OS X sollen bei Apple-Händlern bis Ende Oktober eine kostenlose Update-CD bekommen .
#    10333 | 0.2773 | Nach einer vor kurzem erfolgten Umfrage der Weltbank seien dies nur 37 von 128 Staaten .
#    11367 | 0.2852 | So stehen zum Beispiel michael@musterfamilie.de und gisela@musterfamilie.de für zwei Unterdomains der Domain musterfamilie.de .
#     8299 | 0.3398 | Anders als bei dem Beben vor sechs Wochen gab es auch keine Berichte über schwere Sachschäden .
#     5233 | 0.2188 | Die Talfahrt der High-Tech-Aktien hat am Dienstag gegen Mittag ( Ortszeit ) an den US-Börsen auch die Standardwerte erfasst .
#    16498 | 0.2734 | WebCGM entspricht unter anderem dem Anforderungskatalog , den das W3C Ende Oktober veröffentlicht hat .
#    13432 | 0.2031 | Webring ist ein kostenloser Dienst , über den sich Websites mit gemeinsamen Interessen zusammenschließen können .
#     8312 | 0.3008 | Eine Firma hatte dieses Wort in einem Werbetext als Synonym für Netzwerkverbindungen verwendet , nicht aber als Produktnamen benutzt .
#    17530 | 0.3008 | Für Audi wird Motorola eine neue Lösung zur Vernetzung der Fahrzeuge entwickeln und liefern .
#    16510 | 0.2617 | Es gibt bei Netscape derzeit Überlegungen , dies in einer zukünftigen Version zu ändern .
#    11908 | 0.3359 | Die Musik-Streams kommen mal als RealAudio- , mal als WMA- oder MP3-Datenstrom in den heimischen Rechner .
#     1165 | 0.2773 | AltaVista hat in den USA den kostenlosen Internetzugang FreeAccess gestartet , der sich über Werbung finanziert .
#      142 | 0.2266 | Interpol schätzt , dass rund 80 Prozent des in Umlauf befindlichen Materials aus Japan stammen .
#     7823 | 0.2734 | Neuesten Statistiken zufolge haben die verschiedenen Versionen des Internet Explorer zusammen bereits einen Marktanteil von 64,5 Prozent .
#    16014 | 0.3555 | Zudem scheinen einige Netzwerkbetreiber zunehmend in Zahlungsschwierigkeiten zu kommen und verkaufen ihr gebrauchtes Equipment .
#     6291 | 0.2812 | Die so genannte Erstbeladung werde elf Tage dauern , erklärte ebenfalls nach CTK ein SUJB-Sprecher .
#     3228 | 0.2969 | Ältere Internet-Explorer-Versionen und die Netscape-Browser verlassen sich bei Archiven standardmäßig auf den StuffIt Expander .
#     5278 | 0.2578 | Zugleich geben Potentiometer Rückmeldungen über die ausgeführten Armbewegungen , und Drucksensoren an den synthetischen Fingern ersetzen das natürliche Feingefühl .
#    12447 | 0.3594 | Für ein Mindestgebot von 454,44 US-Dollar stand seit Mittwoch , dem 30. Juni , bei eBay die Wahrheit zur Versteigerung .
#     4259 | 0.3086 | Ab August soll sie in den USA für 49 US-Dollar auch separat erhältlich sein .
#     7849 | 0.1953 | Womöglich könnten Internet-Provider mit Hinweis auf den Smartfilter künftig für Inhalte verantwortlich gemacht werden , so der CCC .
#    12972 | 0.2227 | Die von Corel weitergeführten KPT-Filterpakete umfassen auch " KPT Vector Effects " und die Filterserie " KPT-X " .
#    13998 | 0.1992 | Als Grafikbaustein ist der Nvidia Riva TNT2 M64 mit 32 MByte Bildspeicher ( SDRAM ) vorgesehen .
#      691 | 0.3750 | Diese liegen damit weit unter denen von der Telekom beantragten Preisen von 364,63 bis 581,52 Mark .
#    15540 | 0.2812 | Das Spiel zum Film " Matrix " wird frühestens sechs Monate später auf andere Systeme portiert .
#    14006 | 0.2305 | Damit halbiert sich auch die zur Verfügung stehende Speicherbandbreite , was Auswirkungen auf die Spieleperformance hat .
#    14522 | 0.2500 | Einige davon seien unbemerkt in die Läden gelangt und mit der Artikelnummer 973610 als CD-RWs verkauft wurden .
#    17083 | 0.2617 | Neben den für PDAs üblichen Anwendungen wie Notizblock , Adressbuch oder Kalender glänzt das Gerät mit einem EMail-Client und FAX-Software .
#    15036 | 0.3320 | Das APCN2 bietet insgesamt 64 Wellenlängenkanäle , von denen jeder 10 GBit/s übertragen kann .
#    15559 | 0.2617 | Der schwedische Mobilfunkanbieter Ericsson habe einen Auftrag in gleicher Höhe von Amena erhalten , sagte eine Sprecherin .
#    15560 | 0.3789 | In diesem Jahr sei von Siemens zunächst der Aufbau von 500 Basistationen geplant , hieß es .
#    17608 | 0.2422 | Im Basisgerät wird ein mit 433 MHz getakteter Celeron an Intels 810er Chipsatz betrieben .
#    10954 | 0.2852 | Das alles in kleinen Häppchen , die schnell verwischen und in die nächste Szene überblenden .
#     3791 | 0.2383 | Ab März will das Unternehmen die " Sound Blaster Live! " auch in Deutschland anbieten ; ein Preis ist allerdings noch nicht bekannt .
#     4818 | 0.2773 | Zum einen erlischt die Garantie , zum anderen erfordert das Löten an den filigranen SMD-Bauteilen viel Geschick und das richtige Werkzeug .
#    17107 | 0.2109 | Diese fordert , daß alle Teile eines Programms für jeden frei verfügbar sein müssen .
#     3797 | 0.3047 | Toast zeigte sich auch von einer laufenden PowerPoint-Slideshow unbeeindruckt und brachte den Brennvorgang sicher zu Ende .
#    14553 | 0.2578 | Den Athlon-Nachfolger Thunderbird sollte es offiziell nur für den von AMD neu definierten Sockel A geben .
#      730 | 0.2539 | Das entspräche in etwa der " Full Flatrate " , die die Deutsche Telekom angekündigt hat .
#     9440 | 0.2734 | Wir sehen daher keinen Grund für einen Selbstmord und hoffen auf weitere Ermittlungsergebnisse der Polizei . "
#     6881 | 0.2344 | Mit den Stimmen der Regierungskoalition hat der Bundestag am Freitag das Informations- und Kommunikatonsdienstegesetz ( IuKDG ) beschlossen .
#     8417 | 0.2852 | Die Beratergruppe unterstützt bereits das kanadische Unternehmen MDS Proteomics , an dem IBM beteiligt ist .
#    15075 | 0.3008 | So gewissenhaft wie Creative fragen jedoch nicht alle Firmen ihre Kunden , ob sie die Daten sammeln dürfen .
#    15589 | 0.2266 | Das kompliziertere Wahlsystem habe für die Erfassung der Trendergebnisse keine wesentliche Rolle gespielt , resümierte er am Montag .
#    17127 | 0.2383 | Er besteht bereits aus einzelnen Recheneinheiten , die nur noch entsprechend des Designs verschaltet werden .
#    15081 | 0.2773 | So findet der Musikfreund den Titel seines Lieblingssongs und kann per Mausklick gleich die CD bestellen .
#     3307 | 0.2539 | Im Mai soll es für diese Open-Source-Variante des QuickTime Streaming Server eine neue Version geben .
#    15595 | 0.2734 | Die Anwendungen sollen vom Funktionsumfang mit StarOffice vergleichbar sein ; ein simples Plug-in für den Browser soll für die Nutzung genügen .
#    11507 | 0.2422 | " Das Internet hat sich zur Quasselbude entwickelt " , sagte Arnoud de Kemp vom Heidelberger Springer-Verlag .
#      758 | 0.3008 | Außerdem kann man sich die Oberfläche und Hilfetexte in Deutsch anzeigen lassen .
#    18167 | 0.2695 | Interessant dürfte der Service allenfalls für Nutzer sein , die mal eben schnell von unterwegs eine Nachricht verschicken wollen .
#     3330 | 0.3164 | Nun lenkt der iMac-Cloner ein und akzeptiert eine bereits seit längerem bestehende einstweilige Verfügung :
#    12038 | 0.3555 | Zum Einsatz kommt EIS bereits bei der Messe Frankfurt , wo es Besucher mit verschiedensprachigen Inhalten versorgt .
#    16651 | 0.2461 | Nach einer kurzen Testphase soll ein entsprechender Patch bis Mittwoch , den 18. Juni , auf der Firmenhomepage zur Verfügung gestellt werden .
#    12054 | 0.2812 | " eLiza " heißt das neue Projekt , das IBM heute in Armonk vorstellen will .
#    15126 | 0.2031 | Für das kommende Geschäftsjahr , das am 31. März 2002 endet , erwartet Marconi sogar noch höhere Profite .
#     6426 | 0.2422 | Insofern sei auch das Nato-Truppenstatut , das Aufklärung zur Sicherung der eigenen Truppen erlaubt , nicht die passende Rechtsgrundlage .
#    16675 | 0.1914 | Der kürzlich in Europa aufgeflammte Streit um den Markennamen " Linux " ( siehe http://www.heise.de/newsticker/data/avr-02.09.97-000/ ) ist beigelegt .
#     7460 | 0.2383 | Der medienpolitische Sprecher der FDP-Bundestagsfraktion Hans-Joachim Otto hat heute in Berlin die Gründung der neuen FDP-Internet-Arbeitsgruppe bekanntgegeben .
#     1322 | 0.3438 | SAP meldete in der vergangenen Woche einen unerwartet niedrigen Gewinnanstieg um 15 Prozent für 1998 .
#    10543 | 0.1797 | " Der DoS-Angriff auf die Homepage des Ministeriums ist ein legitimes Mittel , den politischen Willen zum Ausdruck zu bringen . "
#     9521 | 0.2812 | Hier dominiert Windows ( 27% ) vor Solaris ( 25% ) , und der Mac ist mit 11% genauso beliebt wie Linux .
#    17202 | 0.2773 | IBM hielt trotz leicht rückläufiger Umsätze seinen ersten Platz mit 3,2 Milliarden US-Dollar .
#    11062 | 0.2148 | Die Firma hat das Recht , dem Beschluss zu widersprechen , erklärte Richter Wolfgang Rabl gegenüber c't .
#    16191 | 0.1719 | Als Proposed Recommendation hat das World Wide Web Consortium ( W3C ) im Februar MathML , die Mathematical Markup Language , veröffentlicht .
#    11074 | 0.2383 | Zur Zeit prüfen die Münchner , ob ein Widerspruch gegen den Beschluss des Landgerichts überhaupt notwendig ist .
#    12612 | 0.2578 | Im Einstellungsdialog kann der Anwender den Wohnort , das Geburtsjahr ( in Zehnjahresintervallen ) , das Geschlecht , den Zivilstand , das Bildungsniveau und Interessengebiete definieren .
#     5959 | 0.3594 | Opel befindet sich zurzeit - gegen Auflagen - wieder auf freiem Fuß , der zweite Beschuldigte sitzt noch in Haft .
#    11080 | 0.2969 | Was der Terminus " geschützte Partition " im Detail bedeutet , darüber kann man spekulieren .
#    14668 | 0.2773 | Wohin der Code von dort kopiert wurde und wer der Cracker war , ist nicht bekannt .
#    11087 | 0.2500 | Microsoft macht mit seiner neuen Lizenzpolitik die vergleichsweise billigen Großkundenversionen zu einem für den Endkunden weniger wertvollen Produkt .
#    11090 | 0.3438 | Bisher waren auf derartigen Aufnahmen die Atome lediglich als Gesamtheit in Form von Kugeln zu erkennen .
#    17237 | 0.2500 | Für Mitglieder des USB Implementers Forum ist das Kit für 800 US-Dollar ab Juli verfügbar .
#    12632 | 0.2461 | Eine Ausgabe für Mac OS und eine per Odin32 portierte OS/2-Version befinden sich derzeit im Alpha-Stadium .
#     9050 | 0.3203 | NCR will die Herstellung des klugen Eimers nicht selbst übernehmen , sondern möglicherweise in Lizenz vergeben .
#     9562 | 0.2656 | Damit wollen die EU-Mitgliedsstaaten gemeinsam mit den USA , Japan , Kanada und Südafrika gezielt gegen Online-Kriminalität vorgehen .
#     1373 | 0.2930 | Beim Internet-Einkauf müssen die Kunden nach Auffassung der Verbraucherschützer noch immer auf zahlreiche Fallstricke achten .
#     5982 | 0.3086 | Noch läuft das Homebanking weitgehend über T-Online ; bei den privaten Banken beispielsweise gibt es nur 100000 Internetkonten .
#     4447 | 0.2734 | Die bereits im Handel befindlichen Pakete der Software sind von dieser Entscheidung aber nicht betroffen und stehen weiter zum Verkauf .
#    12127 | 0.2461 | Domains , die nach dem automatischen Speichertest daraufhin wieder in Betrieb genommen wurden , seien deshalb sofort wieder abgestürzt .
#     5473 | 0.2305 | Zurzeit liegt der Preis für ein Barrel Rohöl bei 36,06 US-Dollar ; nur knapp unter dem Jahreshoch von 37 Dollar .
#    16738 | 0.2109 | Erst diese ist im Sinne des Konsortiums der Standard , auf dem die Industrie aufsetzen sollte .
#    17255 | 0.2461 | Es sei auch schon ein neues Begleitboot und ein ständiger Betreuer in Sicht , hieß es .
#    18280 | 0.3203 | Ob und wann der EZ2000 in Deutschland auf den Markt kommt , ist noch unklar .
#     3439 | 0.3438 | Für den weiteren Betrieb der Root-Server erhält NSI im Gegenzug eine in der Höhe noch nicht festgesetzte Aufwandsentschädigung .
#    17779 | 0.3008 | PowWow ist hier zu Lande noch nicht sehr bekannt , erfreut sich aber in den USA zunehmender Beliebtheit .
#    11636 | 0.2656 | Ein Präfix-Filter kann die Teile der URL entfernen , mit denen bestimmte Server das Surfverhalten analysieren .
#    18296 | 0.4102 | Die Einrichtung werde allerdings einmalig etwa 100 bis 150 Mark kosten , hieß es heute bei AltaVista .
#    14713 | 0.2734 | " Der Deutsche Bundesrat will per Gesetz erreichen , dass IT-Manager im Stadtverkehr künftig nur noch rechts abbiegen dürfen . "
#    15741 | 0.2500 | Laut Höppner sollen unter der Adresse sachsen-anhalt.de künftig alle Dienstleistungen der öffentlichen Hand gebündelt angeboten werden .
#    13189 | 0.3516 | Laut Adobe war das Problem technischer Natur ; man habe das Update keinesfalls zurückziehen wollen .
#    12683 | 0.3320 | Vorsätzliche Links auf andere Websites , die DeCSS zum Download anbieten , verbot der Richter gleich mit .
#     4491 | 0.3867 | Beide Geräte sollen im Mai auf den Markt kommen und 399 respektive 99 Mark kosten .
#      413 | 0.2539 | So sollte beispielsweise c't-Leser Jochen R. für seinen Palm m100 643,47 statt 329 Mark bezahlen .
#     1438 | 0.2656 | " Man darf bei alldem nicht vergessen , dass wir die Kunden und das Kapital haben . "
#      928 | 0.2500 | AOL hatte in USA nach der Einführung des Pauschalpreises im Dezember 1996 einen wahren Boom erlebt .
# ...
#     9687 | 0.2188 | Neu freilich ist , dass die Versuche , die Websites des Gegners durch DoS-Angriffe lahmzulegen , nicht von einzelnen ausgehen , sondern eine Angelegenheit von vielen Menschen geworden sind .
#    14046 | 0.2539 | Nachdem sich Asus zunächst nicht so recht zum eigenen Athlon-Board K7M bekennen wollte , liefert die Firma jetzt doch ein Minimum an Support für die als OEM-Produkt verkauften Boards .
#     6381 | 0.2422 | Aber der größte Teil des Materials , das bei " Trend " gespeichert war , ist vorerst offline , weil bei Compuserve nur zwei MB abgelegt werden können .
#    10990 | 0.3164 | Die Gesamtrechnung geht nur auf , wenn die beiden Hauptfaktoren Eintrittspreise und Besucherzahlen in etwa so bleiben beziehungsweise werden , wie man sie im Vorfeld geplant hat .
#     1263 | 0.2188 | Ende Juli hatte die RIAA eine einstweilige Verfügung gegen Napster erwirkt , wonach alle Server des Dienstes , über die urheberrechtlich geschützte Werke verbreitet werden , vom Netz gehen sollten .
#    16882 | 0.2227 | Bei einer Einstiegsausstattung von 16 Prozessoren und 2 GByte Festplatte soll die E 10000 etwa 2 Mio. Mark kosten und ab März verfügbar sein .
#     6131 | 0.2734 | In dem von Statewatch veröffentlichten Papier , das auch Telepolis vorliegt , wird jedoch darüber hinausgehend gefordert , dass Europol solche gemeinsamen Ermittlungen und Ermittlungsteams auch leiten kann .
#    13953 | 0.2148 | Schließlich demonstrieren Micron , Hyundai und demnächst vielleicht auch Infineon ja gerade eindrucksvoll , wie es einer Firma ergehen kann , die sich auf Patente beruft , die als JEDEC-Standard festgeschrieben wurden .
#     3170 | 0.2617 | Dem juristischen Nachrichtendienst The Recorder zufolge haben die Apple-Anwälte außerdem eine Vereinbarung zwischen Shalit und einem frühreren Arbeitgeber als Beweis vorgelegt , die die Rechte an den fraglichen Techniken diesem Unternehmen zuspricht .
#    11844 | 0.3164 | Die Datenschützer erinnerten sich noch mit Schrecken an den Mitte vergangenen Jahres pleite gegangenen Spielzeughändlers Toysmart , an dem Disney über seine Tochter Buena Vista mit 60 Prozent Mehrheitseigner war .
#    10686 | 0.2695 | Künftig sollen beispielsweise auch diejenigen strafrechtlich verfolgt werden können , die einen Link auf einen " volksverhetzenden Inhalt " setzen - und zwar selbst dann , wenn der Betreffende sich den Inhalt nicht zu Eigen macht .
#    16070 | 0.3320 | 79 Prozent der Firmenchefs seien der Meinung , dass in ihr E-Commerce-System sehr wahrscheinlich von außen über das Internet oder andere Zugangsmöglichkeiten eingebrochen werde , schreibt die KPMG .
#    15272 | 0.3320 | Am Wochenanfang hatte bereits Ericsson die weltweiten Hightech-Märkte in die Tiefe gerissen , als der Konzern einen Verlust in Milliardenhöhe für das erste Quartal ankündigte und eine Gewinnwarnung für das Gesamtjahr abgab .
#    11501 | 0.2695 | Auf der noch bis Donnerstag in Frankfurt stattfindenden Jahrestagung der Deutschen Gesellschaft für Informationswissenschaft und Informationspraxis ( DGI ) beklagte DGI-Präsident Horst Neißer , dass auf dem Informationssektor im Internet eine Wildwest-Mentalität herrsche .
#    15693 | 0.3438 | Wegen eines Softwarefehlers müssen alle 10.142 Wahlzettel , auf denen die Bürger bei der Kommunalwahl in Hessen kumuliert und panaschiert haben , von Hand neu ausgezählt werden , meldete am gestrigen Dienstag die Wetzlarer Neue Zeitung .
#    12698 | 0.2969 | Im Interview differenzierte er die eingangs zitierten Aussagen durch die Feststellung , es ginge hier um wirtschaftliche Fragen zwischen zwei Unternehmen mit unterschiedlichen Interessen , wobei die Bundesregierung durch ihre Beteiligung an der Telekom zwischen den Fronten stehe .
#    14357 | 0.2500 | Mit der heute offiziell vorgestellten 933-MHz-Version des Pentium III schließt Intel die bis dahin klaffende Frequenzlücke zwischen dem GHz-Modell , das im Handel bislang nur in minimalen Stückzahlen aufgetaucht ist , und dem Pentium-III-866 .
#    10038 | 0.2656 | Als Grund für die Ausschreibung des Preises geben die Organisatoren an , dass die technischen Möglichkeiten des Sammelns und Auswertens elektronischer Informationen immer mehr Organisationen zum Missbrauch verführe .
#     8437 | 0.3008 | Zusammen mit nVidias neuestem Grafikprozessor GeForce 256 und einer angepassten Version des Betriebssystems Windows CE erreiche die X-Box die gleiche Leistung wie die derzeit von Sony entwickelte Playstation 2 , heißt es weiter .
#     4373 | 0.2344 | Um der Sicherheitslücke aus dem Weg zu gehen , hilft zur Zeit nur das Deaktivieren der MRJ oder der Umstieg auf den Netscape Communicator ( ohne MRJ-Plugin ) , dessen Java-Umgebung nicht von dem Problem betroffen zu sein scheint .
#     7262 | 0.2383 | Wie ein internes Dokument der Europol , das Telepolis vorliegt , beweist , sind derzeit massive Bestrebungen der europäischen Polizeibehörden im Gange , das im Aufbau befindliche Iridium-System in den Abhörgriff zu bekommen .
#      538 | 0.3086 | Und nicht genug damit , dass jedermann mit ShareSniffer die offenen Hintertüren aufspüren kann , das Programm bietet auch noch die Möglichkeit , IP-Adressen potentieller Opfer , die es aufgespürt hat , automatisch in Newsgroups zu veröffentlichen .
#     2494 | 0.2227 | Pünktlich zur CeBIT erhielt auch die Münchner CpayS AG , ein Tochterunternehmen von Giesecke & Devrient , die begehrte Zulassung für seine CashMouse , mit der auch das Aufladen der GeldKarte über das Internet möglich sein soll .
#     7017 | 0.2734 | Laut Schmid sei es unter diesem Ausgangspunkt derzeit nicht beweisbar , ob nachrichtendienstliche Erkenntnisse " gezielt einzelnen Unternehmen zugeleitet wurden " ; doch die Wirtschaft sollte sich auf die Möglichkeit der Wirtschaftsspionage einstellen .
#    14039 | 0.2656 | Damit schafft es Intel nun zwar zur Comdex , einen adäquaten Chipsatz für die eigenen Prozessoren mit 133 MHz Frontside Bus ( FSB ) anzubieten , umschifft den Bug beim Betrieb mit drei RIM-Modulen aber höchst unelegant .
#    14635 | 0.1953 | Da stellt sich die Frage , ob der Pentium 4 wirklich schon bereit ist , um die Nachfolge des Pentium III anzutreten , der sich nach Firmenangaben von allen Intel-CPUs bisher am besten verkauft hat .
#    13362 | 0.3125 | Für den Privatanwender ist das Programm kaum interessant - die Datenströme eines durchschnittlichen Films verschlingen etwa drei bis vier GigaByte Speicherplatz und sind damit auf DVD-Silberlingen wesentlich besser aufgehoben als auf der Festplatte .
#     1079 | 0.3125 | Zwei Schüler haben offenbar ein Programm mit versteckter Schadfunktion ( trojanisches Pferd ) in Umlauf gebracht , das Namen und Paßwörter bei der Eingabe in die AOL-Zugangssoftware mitliest und per E-Mail an die Hacker überträgt .
#    16185 | 0.2461 | In seinem Advisory CA-2000-02 bezeichnet die Gruppe die Elemente embed , script , object und applet als gefährlich , weil sie - in einer HTML-Seite oder E-Mail enthalten - vom Anwender nicht kontrollierbare Programme ausführen können .
#    13504 | 0.2305 | Ohne Java-Unterstützung umfasst der Opera-Download gerade mal 1,8 MByte , auch inklusive Suns Java 2 Runtime Environment landen nur 9,3 MByte auf der Festplatte - nur wenig mehr als die Minimalinstallation von Netscape 6 ( ohne Java ) .
#     8801 | 0.3320 | Die Angestellten könnten als Miteigentümer zwar auch in den turnusmäßigen Mitarbeiterversammlungen von den Geschäftsführern Rede und Antwort verlangen , aber " sollte es zu unplanmäßigen Entwicklungen kommen , ist es sicherlich gut , wenn auch Vertretungen organisiert sind " .
#    11170 | 0.2266 | Das kanadische Spezialunternehmen Cold North Wind konnte dafür gewonnen werden , sich durch die gesammelten Werke der letzten zweihundert Jahre zu wühlen und sie der interessierten Öffentlichkeit im Internet zugänglich zu machen .
#    15016 | 0.3242 | Gegen eine Anzahlung von 100 Mark wird der Wagen vorreserviert ; ein Kundenberater von Opel vereinbart einen Termin beim nächsten Vertragshändler , wo auf Wunsch eine Probefahrt möglich ist und der endgültige Kaufvertrag unterschrieben wird .
#     9354 | 0.2891 | Jim Guerinot , der Manager der Band , sagte am Montag , die Band habe sich mit der Plattenfirma geeinigt und werde nun nicht mehr ihre ganze CD " Conspiracy of One " ins Netz stellen , sondern nur noch einen Song .
#    15338 | 0.2422 | Ziel des DVB-Konsortiums ist es , mittels MHP einen horizontalen Markt zu schaffen , in dem alle Hersteller den gleichen Standard benutzen und alle Konsumenten nur noch eine einzige Settop-Box oder Fernseher mit eingebautem Decoder ( iDTV ) brauchen .
#     2896 | 0.4141 | Den Gerüchten nach , die von Unternehmenskreisen lanciert wurden , plant die Telekom , ihr Tarifmodell zu vereinfachen , indem sie im kommenden Jahr nur noch zwischen zwei Entfernungs- und zwei Zeitzonen unterscheiden will .
#    14674 | 0.2227 | Zwar ist noch nicht klar , in welchen der 17 von UPC belieferten Länder Liberate zum Zuge komme , das US-Blatt schätzt aber , dass Liberate mit Lizenz-Einnahmen in mehrstelliger Millionenhöhe rechnen könne .
#     8150 | 0.2969 | Obwohl der Gesetzgeber drei Jahre Zeit hatte und seit dem Oktober 1998 sogar Bußgelder der EU-Kommission drohen , wurden das Bundes- und die meisten Länderdatenschutzgesetze bis heute nicht an die EU-Richtlinie angepaßt .
#    12410 | 0.1836 | Im Revisionsverfahren stand dem Anwalt der Klägerpartei Daniel Alter zur Seite , der im Auftrag der US-Regierung für die Position der Studios plädierte - die US-Staatsanwaltschaft hatte Ende Februar ein Expertenschreiben ( " Amicus Curiae " ) eingereicht , um die Position der Filmstudios zu stützen .
#      124 | 0.3242 | In einem offenen Brief an das US-Justizministerium hatte Netscape Mitte August Microsoft bezichtigt , Hardware-Herstellern einen Preisnachlaß von 3 US-Dollar auf jede Windows-95-Lizenz angeboten zu haben , sofern diese als Web-Browser nur den Internet Explorer mitliefern würden .
#     1602 | 0.2500 | Als AOL-Mitglieder im Internet mit Pornos gehandelt hatten , ließ sich die Hamburger Staatsanwaltschaft im September vergangenen Jahres davon überzeugen , daß der Online-Dienst keine wirkungsvolle Kontrolle auf die Inhalte des Internet ausüben könne , und erhob keine Anklage .
#    10755 | 0.2617 | Napster aber konnte noch in einer vom Berufungsgericht des 9. US-Justizbezirks erfolgten Eilentscheidung erreichen , dass die einstweilige Verfügung aufgehoben wurde und die Server so am Netz bleiben konnten , weil Fragen über Begründung und Form der einstweiligen Verfügung aufgetaucht seien .
#     9701 | 0.2617 | Die Gegenseite denkt freilich nicht an einen Waffenstillstand im Cyberspace , sondern feiert , dass " arabische Internetnutzer auf der ganzen Welt in einem Gegenangriff auf die Versuche , die Hisbollah-Seiten auszuschalten , zwei große israelische Websites am Mittwoch lahm legen konnten . "
#    16182 | 0.2891 | Die Summe der unter NT arbeitenden HTTP-Daemonen beziffert Netcraft mit 21,1 % - allerdings beinhaltet diese Angabe nicht diejenigen NT-Webserver , die mit Netscapes oder Navisofts Software arbeiten , da sie sich nicht unterschiedlich ( nach Betriebssystem ) melden .
#     2809 | 0.3047 | Schaut sich ein Anwender diese Seite mit dem Internet Explorer an und hat er die Homebanking-Software Quicken auf seinem Rechner installiert , so startet das Control diese im Hintergrund und fügt unbemerkt einen Geldtransaktionssatz in die entsprechende Datei ein .
#    10234 | 0.2695 | Neu sei , daß man nicht mehr mit den Angriffen einzelner Hacker zu rechnen habe , sondern mit koordinierten Versuchen , bei denen mehrere Hacker von verschiedenen IP-Adressen aus agieren , die sich manchmal auch in anderen Ländern oder sogar anderen Kontinenten befinden .
#    10229 | 0.2305 | Die Staatsanwälte versuchen nach Microsoft , die Gesetze ihrer Bundesstaaten gegen das Recht auf geistiges Eigentum durchzusetzen und das Unternehmen dazu zu zwingen , " veränderte oder abgespeckte Versionen von Windows 95 und Windows 98 zu vertreiben . "
#     3515 | 0.3281 | Besonders die Tatsache , dass sich Steve Jobs und sein gesamtes Management-Team höchstpersönlich nach Paris bemühen und Apple seinen Auftritt im Internet übertragen will , werten Branchenkenner als Zeichen , dass der Apple-Chef noch einen Trumpf in der Hinterhand hat .
#     1277 | 0.2656 | Man kann über AutoEuro.de Tests der Zeitschrift " Auto Bild " abrufen , sich über Finanzierungs- und Leasingkonditionen von 21 Autobanken informieren und den von der Deutsche Automobil Treuhand GmbH ermittelten Wert eines Gebrauchtwagens abfragen .
#     3272 | 0.2266 | Die Preise dürften sich an den bisherigen Produkten orientieren : die aktuelle Release 4 kostet 1119 DM , die funktionsgleiche Academic-Version für Schüler , Studenten und Bildungseinrichtungen , mit der keine kommerziellen Programme erstellt werden dürfen , schlägt mit 295 DM zu Buche
#    10288 | 0.2422 | Wenn sich Dale und Lorrie am letzten Tag des Jahres in der Kirche von Hollisdaysburg in Pennsylvania die Ehe versprechen , wird der Pastor zwar seine segnende Worte sprechen , den beiden frisch Vermählten aber nicht per Handschlag gratulieren oder ihnen das Abendmahl reichen können .
#     5339 | 0.2266 | Zum dritten Jahrestag der Gründung im März 2000 verzeichnet der Neue Markt 231 Unternehmen mit einer Marktkapitalisierung von über 400 Milliarden Mark ( über 200 Milliarden Euro ) ; allein ein Erfolgsunternehmen wie EM-TV bringt rund 12 Milliarden auf die Waage und damit mehr als einige DAX-Unternehmen zusammen .
#     3078 | 0.1641 | Das unter dem Namen " PocketMac " entwickelte Programm soll es nach Angaben der Entwickler aus dem sonnigen La Jolla in Kalifornien erstmals erlauben , Adressen , Termine und Aufgaben zwischen Pocket-PC und Microsoft Entourage , dem PIM aus dem Office-Paket , abzugleichen .
#    10167 | 0.1719 | Mit der Zustimmung des Innenministers könnte die ASIO ( Australian Security Intelligence Organization ) in Zukunft durch " remote access " Zugang zu einem Computer und zu Netzwerken erhalten , also in einen Computer oder einen Server eindringen und Daten kopieren , hinzufügen , verändern oder löschen , was bislang gesetzlich verboten war .
#     9840 | 0.1992 | Kritik muss sich der Europarat auch aus Berlin gefallen lassen , wo sich Bundestagsabgeordnete und Ministerien nach wie vor trotz Veröffentlichung der Enfopol-Papiere sowie der ETSI-Dossiers fragen , wie das Thema Cybercrime überhaupt auf die Tagesordnung des sonst weit gehend über so " profanen " Dingen wie Computersicherheit stehenden Gremiums gelangen konnte .
#     5587 | 0.2812 | So hatte sich die Telekom gezwungen gesehen , die Zeichnungsspanne von 26 bis 32 Euro nicht auszureizen , sondern den Emissionspreis mit 27 Euro am unteren Ende anzusiedeln - das unrühmliche Beispiel von Lycos Europe vermutlich noch in frischer Erinnerung , deren hoch angesetzte Aktie sofort nach Börsenstart am 22. März ins Trudeln kam und heute um ein Drittel niedriger notiert wird .
#     9316 | 0.2578 | Grundlage des Berichts " The Internet as a Newly Emerging Risk Environment for Sexually Transmitted Diseases " , der in der aktuellen Ausgabe des Journal of the American Medical Association veröffentlicht wurde , ist eine Befragung von über 800 Menschen ab 18 Jahren , die sich zwischen September 1999 und April 2000 an der Denver Public Health HIV Counseling and Testing Site ( DPHHCTS ) über HIV-Tests informiert haben .
#     9536 | 0.1992 | Entgegen aller Strategien , in der Informationsgesellschaft mit dem Einsatz aller Medien Wahlkampf zu führen , hat es die DVU bei der Landtagswahl in Sachsen-Anhalt geschafft , erdrutschartige Gewinne davonzutragen und von Null auf 13 Prozent zu springen , während die CDU eine große Niederlage erlitt , die SPD und die PDS sich halten konnten , die Grünen und die FDP an der Fünf-Prozent-Hürde gescheitert sind .
